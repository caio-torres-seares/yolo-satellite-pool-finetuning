# %% [markdown]
# ## 1. Install libs

# %%
import torch
import numpy as np
import yaml
from ultralytics import YOLO
from pathlib import Path
import cv2
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import shutil
import os

import xml.etree.ElementTree as ET
import glob
import json

# Configuração para que os gráficos apareçam no notebook
# %matplotlib inline

print("Libraries successfully imported!")
# Out:
# Libraries successfully imported!

# %% [markdown]
# ### Global Base Path

# %%
# Pega o diretório atual automaticamente
BASE_DIR = Path().resolve()

# Sobe um nível e entra na pasta dataset
DATASET_DIR = BASE_DIR.parent / "dataset"

print("Current path:", BASE_DIR)
print("Dataset path:", DATASET_DIR)
# Out:
# Current path: C:\Users\Seares\Desktop\Programação\Projetos\Cases Técnicos\CloudWalk-case\notebooks
# Dataset path: C:\Users\Seares\Desktop\Programação\Projetos\Cases Técnicos\CloudWalk-case\dataset

# %% [markdown]
# ### Auxiliary Functions

# %%
def xml_to_yolo_bbox(bbox, w, h):
    # xmin, ymin, xmax, ymax
    x_center = ((bbox[2] + bbox[0]) / 2) / w
    y_center = ((bbox[3] + bbox[1]) / 2) / h
    width = (bbox[2] - bbox[0]) / w
    height = (bbox[3] - bbox[1]) / h
    return [x_center, y_center, width, height]


def yolo_to_xml_bbox(bbox, w, h):
    # x_center, y_center width heigth
    w_half_len = (bbox[2] * w) / 2
    h_half_len = (bbox[3] * h) / 2
    xmin = int((bbox[0] * w) - w_half_len)
    ymin = int((bbox[1] * h) - h_half_len)
    xmax = int((bbox[0] * w) + w_half_len)
    ymax = int((bbox[1] * h) + h_half_len)
    return [xmin, ymin, xmax, ymax]

# %% [markdown]
# ## 2. Convert the labels: PASCAL VOC (XML) to YOLO (TXT)

# %%
classes = []
input_dir = "../dataset/sp-pools/labels/"
output_dir = "../dataset/sp-pools_labels_yolo/"
image_dir = "../dataset/sp-pools/images/"

# create the labels folder (output directory)
if not os.path.isdir(output_dir):
    os.mkdir(output_dir)

# identify all the xml files in the annotations folder (input directory)
files = glob.glob(os.path.join(input_dir, '*.xml'))

for fil in files:
    basename = os.path.basename(fil)
    filename = os.path.splitext(basename)[0]
    # check if the label contains the corresponding image file
    if not os.path.exists(os.path.join(image_dir, f"{filename}.png")):
        print(f"{filename} image does not exist!")
        continue

    result = []

    # parse the content of the xml file
    tree = ET.parse(fil)
    root = tree.getroot()
    width = int(root.find("size").find("width").text)
    height = int(root.find("size").find("height").text)

    for obj in root.findall('object'):
        label = obj.find("name").text
        # check for new classes and append to list
        if label not in classes:
            classes.append(label)
        index = classes.index(label)
        
        bbox = obj.find("bndbox")
        xmin = int(bbox.find("xmin").text)
        ymin = int(bbox.find("ymin").text)
        xmax = int(bbox.find("xmax").text)
        ymax = int(bbox.find("ymax").text)
        


        pil_bbox = [xmin, ymin, xmax, ymax]

        yolo_bbox = xml_to_yolo_bbox(pil_bbox, width, height)

        # convert data to string
        bbox_string = " ".join([str(x) for x in yolo_bbox])
        result.append(f"{index} {bbox_string}")

    if result:
        # generate a YOLO format text file for each xml file
        with open(os.path.join(output_dir, f"{filename}.txt"), "w", encoding="utf-8") as f:
            f.write("\n".join(result))

# generate the classes file as reference
with open('classes.txt', 'w', encoding='utf8') as f:
    f.write(json.dumps(classes))
    
print("XML to YOLO Format Done!!")
# Out:
# XML to YOLO Format Done!!

# %%
## Just for visualization the image from dataset

img = cv2.imread("../dataset/sp-pools/images/sp_Alto_de_Pinheiros_0245_-23.554000_-46.716714.png")
dh, dw, _ = img.shape

fl = open("../dataset/sp-pools_labels_yolo/sp_Alto_de_Pinheiros_0245_-23.554000_-46.716714.txt", 'r')
data = fl.readlines()
fl.close()

for dt in data:

    _, x, y, w, h = map(float, dt.split(' '))

    l = int((x - w / 2) * dw)
    r = int((x + w / 2) * dw)
    t = int((y - h / 2) * dh)
    b = int((y + h / 2) * dh)
    
    if l < 0:
        l = 0
    if r > dw - 1:
        r = dw - 1
    if t < 0:
        t = 0
    if b > dh - 1:
        b = dh - 1

    cv2.rectangle(img, (l, t), (r, b), (0, 0, 255), 1)

plt.imshow(img)
plt.show()

# %% [markdown]
# ## 3. Train Test Split

# %%
IMAGES_PATH = DATASET_DIR / "sp-pools/images"
LABELS_PATH = DATASET_DIR / "sp-pools_labels_yolo/"

OUTPUT_SPLIT_DIR = DATASET_DIR / "fine_tuning/yolo_dataset_split"

all_images = [file for file in os.listdir(IMAGES_PATH) if file.endswith('.png')]

images_with_labels = []
images_without_labels = []

for img_file in all_images:
    label_file = f"{img_file[:-4]}.txt"
    if os.path.exists(LABELS_PATH / label_file):
        images_with_labels.append(img_file)
    else:
        images_without_labels.append(img_file)

print(f"Imagens COM piscinas: {len(images_with_labels)}")
print(f"Imagens SEM piscinas: {len(images_without_labels)}")

all_images_for_split = images_with_labels + images_without_labels

# Split data
train, temp = train_test_split(all_images_for_split, test_size=0.3, shuffle=True, random_state=42)
valid, test = train_test_split(temp, test_size=0.5, shuffle=True, random_state=42)

print(f"train: {len(train)}; valid: {len(valid)}; test: {len(test)}")

os.makedirs(OUTPUT_SPLIT_DIR / "test/images", exist_ok=True)
os.makedirs(OUTPUT_SPLIT_DIR / "test/labels", exist_ok=True)
os.makedirs(OUTPUT_SPLIT_DIR / "train/images", exist_ok=True)
os.makedirs(OUTPUT_SPLIT_DIR / "train/labels", exist_ok=True)
os.makedirs(OUTPUT_SPLIT_DIR / "valid/images", exist_ok=True)
os.makedirs(OUTPUT_SPLIT_DIR / "valid/labels", exist_ok=True)

def move_files_to_dir(image_files, dirname):
    for image_filename in image_files:
        label_filename = f"{image_filename[:-4]}.txt"
        
        shutil.copy(f"{IMAGES_PATH}/{image_filename}", f"{dirname}/images/{image_filename}")
        
        if os.path.exists(f"{LABELS_PATH}/{label_filename}"):
            shutil.copy(f"{LABELS_PATH}/{label_filename}", f"{dirname}/labels/{label_filename}")
        else:
            # Make empty file for images without pools
            open(f"{dirname}/labels/{label_filename}", 'w').close()

# Move splits to folders
move_files_to_dir(train, OUTPUT_SPLIT_DIR / "train")
move_files_to_dir(test, OUTPUT_SPLIT_DIR / "test")
move_files_to_dir(valid, OUTPUT_SPLIT_DIR / "valid")

print("Train Test Split Done!!")
print("Folders Local: ", OUTPUT_SPLIT_DIR)
# Out:
# Imagens COM piscinas: 116
# Imagens SEM piscinas: 191
# train: 214; valid: 46; test: 47
# Train Test Split Done!!
# Folders Local:  C:\Users\Seares\Desktop\Programação\Projetos\Cases Técnicos\CloudWalk-case\dataset\fine_tuning\yolo_dataset_split

# %% [markdown]
# ## 4. Training Model

# %% [markdown]
# ### Create a dataset yaml config

# %%
def create_dataset_yaml():
    """
    Create config file for dataset
    """
    absolute_split_path = os.path.abspath(OUTPUT_SPLIT_DIR)
    
    dataset_config = {
        'path': absolute_split_path,
        
        'train': 'train/images',
        'val': 'valid/images',
        'test': 'test/images',
        
        'nc': 1,            # Number of classes (Just one: pool)
        'names': ['pool']   # Name of the classes (index 0)
    }

    yaml_path = os.path.join(DATASET_DIR, 'fine_tuning/fine_tuning.yaml')

    with open(yaml_path, 'w') as f:
        yaml.dump(dataset_config, f, default_flow_style=False)

    print(f"Arquivo dataset.yaml criado: {yaml_path}")
    return yaml_path

# %%
yaml_config = create_dataset_yaml()
# Out:
# Arquivo dataset.yaml criado: C:\Users\Seares\Desktop\Programação\Projetos\Cases Técnicos\CloudWalk-case\dataset\fine_tuning/fine_tuning.yaml

# %%
model_path = '../models/results_pools/pools_detector_v4/weights/best.pt'
model = YOLO(model_path)

os.makedirs('../models/fine_tuning', exist_ok=True)

results = model.train(
    data=yaml_config,
    epochs=80,
    imgsz=512,  
    batch=16,    # ajustado pra 8GB de VRAM
    device=0 if torch.cuda.is_available() else 'cpu',
    project='../models/fine_tuning',
    name='pools_fine_tuning_v3',
    save=True,
    plots=True,
    patience=15,
    verbose=True,
    exist_ok=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.221 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.218  Python-3.10.18 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\dataset\fine_tuning/fine_tuning.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../models/results_pools/pools_detector_v4/weights/best.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=pools_fine_tuning_v3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../models/fine_tuning, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\models\fine_tuning\pools_fine_tuning_v3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, [192, 384, 576]]
# Model summary: 169 layers, 25,856,899 parameters, 25,856,883 gradients, 79.1 GFLOPs
#
# Transferred 475/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 33.36.7 MB/s, size: 165.2 KB)
# train: Scanning C:\Users\Seares\Desktop\Programação\Projetos\Cases Técnicos\CloudWalk-case\dataset\fine_tuning\yolo_dataset_split\train\labels... 214 images, 135 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 214/214 1.2Kit/s 0.2s0.3s
# train: New cache created: C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\dataset\fine_tuning\yolo_dataset_split\train\labels.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 22.63.1 MB/s, size: 172.6 KB)
# val: Scanning C:\Users\Seares\Desktop\Programação\Projetos\Cases Técnicos\CloudWalk-case\dataset\fine_tuning\yolo_dataset_split\valid\labels... 46 images, 33 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 46/46 707.8it/s 0.1s
# val: New cache created: C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\dataset\fine_tuning\yolo_dataset_split\valid\labels.cache
# Plotting labels to C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\models\fine_tuning\pools_fine_tuning_v3\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\models\fine_tuning\pools_fine_tuning_v3
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      4.19G      1.782      2.116       1.57          9        512: 100% ━━━━━━━━━━━━ 14/14 2.8it/s 5.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.3it/s 0.4s0.8s
#                    all         46         23      0.419      0.261      0.341      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      4.08G      1.524      1.236      1.431          6        512: 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.9it/s 0.4s0.8s
#                    all         46         23      0.495      0.652      0.537      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      4.18G      1.481      1.222      1.462          2        512: 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s1.1s
#                    all         46         23      0.505      0.435      0.423      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      4.17G      1.369     0.9627      1.385          9        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.6it/s 0.4s0.8s
#                    all         46         23      0.583      0.565      0.584      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      4.17G      1.448      1.013      1.345          4        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.4it/s 0.4s0.9s
#                    all         46         23      0.733      0.652      0.684      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      4.18G      1.435      1.195      1.365          5        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s0.8s
#                    all         46         23       0.73      0.522       0.66      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      4.09G       1.29      1.056      1.273          8        512: 100% ━━━━━━━━━━━━ 14/14 4.0it/s 3.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s0.8s
#                    all         46         23      0.625      0.609      0.545      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      4.16G      1.307      1.006        1.3          8        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.2it/s 0.4s0.9s
#                    all         46         23      0.553      0.593      0.554      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      4.08G      1.333      1.117      1.309          1        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.4it/s 0.4s0.9s
#                    all         46         23      0.603      0.529      0.599      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      4.16G      1.281       1.01      1.236         10        512: 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.2it/s 0.4s0.9s
#                    all         46         23      0.558      0.565      0.554      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      4.08G      1.226     0.8324      1.285          8        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.0it/s 0.4s1.0s
#                    all         46         23      0.613      0.609      0.609      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      4.16G      1.385      0.983      1.307          9        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.4it/s 0.4s0.9s
#                    all         46         23      0.773      0.594      0.675      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      4.08G      1.252     0.9697      1.252          3        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.5it/s 0.4s0.9s
#                    all         46         23      0.845      0.475      0.565      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      4.17G      1.239     0.9876       1.24          8        512: 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s0.8s
#                    all         46         23      0.625      0.478      0.451      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      4.08G       1.25     0.8713      1.252          4        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.6it/s 0.4s0.8s
#                    all         46         23      0.751      0.522      0.601      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      4.18G      1.243     0.9269      1.323          7        512: 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s0.8s
#                    all         46         23       0.85      0.522      0.627      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      4.08G      1.136     0.8031       1.21          6        512: 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.2it/s 0.4s0.9s
#                    all         46         23      0.838      0.478      0.557      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      4.15G      1.247     0.8705      1.202          6        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.4it/s 0.4s0.8s
#                    all         46         23       0.71      0.652      0.654      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      4.07G      1.238     0.9013      1.236          6        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s1.1s
#                    all         46         23      0.706      0.652      0.683      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      4.17G      1.208     0.8554      1.203          2        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.1it/s 0.3s0.8s
#                    all         46         23      0.855      0.522      0.652      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      4.08G      1.114     0.8511      1.179          8        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.7it/s 0.4s0.8s
#                    all         46         23      0.725      0.574       0.63      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      4.18G      1.171     0.8463      1.213          5        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.5it/s 0.4s0.8s
#                    all         46         23      0.677      0.549      0.609      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      4.08G      1.182     0.8573      1.272          4        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s1.2s
#                    all         46         23      0.771      0.587      0.636      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      4.17G      1.224      0.902      1.211          9        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s0.8s
#                    all         46         23      0.665      0.565      0.591      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      4.08G      1.128     0.8103      1.199          6        512: 100% ━━━━━━━━━━━━ 14/14 3.9it/s 3.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s0.8s
#                    all         46         23      0.753       0.53      0.587       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      4.17G      1.187     0.8649      1.243          6        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.6it/s 0.4s0.8s
#                    all         46         23      0.649      0.739      0.648      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      4.08G      1.099     0.7478      1.191          4        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s0.8s
#                    all         46         23      0.797      0.565      0.632      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      4.17G      1.148     0.7504      1.263          8        512: 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.4it/s 0.4s0.9s
#                    all         46         23       0.78      0.464      0.559      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      4.09G      1.207     0.7599      1.239          8        512: 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.6it/s 0.4s0.8s
#                    all         46         23      0.861      0.391      0.566      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      4.17G      1.086     0.7552      1.165          4        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.5it/s 0.4s0.8s
#                    all         46         23      0.783      0.435        0.6       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      4.09G      1.093     0.7253      1.193         10        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.4it/s 0.4s0.9s
#                    all         46         23      0.585      0.478      0.573      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      4.18G      1.113     0.7597      1.182         10        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.6it/s 0.4s0.8s
#                    all         46         23      0.748      0.435      0.546      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      4.09G      1.129     0.6954      1.174         11        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.4it/s 0.4s0.9s
#                    all         46         23      0.712      0.644      0.695      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      4.16G      1.014     0.6902      1.149          6        512: 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.1it/s 0.4s0.8s
#                    all         46         23      0.802      0.522        0.7      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      4.08G      1.045      0.764      1.115          4        512: 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.7it/s 0.3s0.8s
#                    all         46         23      0.981      0.478      0.663      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      4.17G      1.031     0.7005      1.175          4        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.4it/s 0.4s0.9s
#                    all         46         23          1      0.516      0.732      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      4.09G          1     0.6967      1.131         10        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s0.8s
#                    all         46         23      0.727      0.609      0.683      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      4.16G       1.06     0.7332      1.141          5        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.7it/s 0.4s0.8s
#                    all         46         23      0.664      0.609      0.653      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      4.07G     0.9542     0.7077      1.086          0        512: 100% ━━━━━━━━━━━━ 14/14 3.9it/s 3.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s0.8s
#                    all         46         23      0.832      0.478      0.602      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      4.16G      1.003     0.7171      1.145          3        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.0it/s 0.4s0.8s
#                    all         46         23       0.82      0.478      0.672       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      4.08G     0.9972     0.6457      1.095          5        512: 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.2it/s 0.4s0.9s
#                    all         46         23      0.593      0.739      0.665      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      4.17G     0.9536     0.6556      1.118          4        512: 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.4it/s 0.4s0.9s
#                    all         46         23      0.608      0.652      0.661      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      4.08G     0.9374     0.6396      1.112          9        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.4it/s 0.4s0.9s
#                    all         46         23      0.736      0.565      0.623      0.411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      4.15G      1.021     0.6721      1.103         13        512: 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.5it/s 0.4s0.8s
#                    all         46         23      0.617      0.561      0.541       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      4.08G     0.9556     0.5798      1.112          4        512: 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.1it/s 0.4s0.9s
#                    all         46         23      0.721      0.478      0.544      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      4.17G     0.9107     0.6123       1.05          5        512: 100% ━━━━━━━━━━━━ 14/14 3.4it/s 4.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.6it/s 0.4s0.8s
#                    all         46         23      0.845      0.474      0.605      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      4.08G     0.9413     0.5416      1.075          6        512: 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.6it/s 0.4s0.8s
#                    all         46         23      0.849      0.478      0.628      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      4.17G     0.9289     0.5967      1.082         11        512: 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.6it/s 0.4s0.8s
#                    all         46         23      0.868      0.522      0.622      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      4.08G     0.9378     0.6033       1.03          8        512: 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.7it/s 0.4s0.8s
#                    all         46         23      0.792      0.565      0.603      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      4.17G     0.8746     0.5373      1.055          4        512: 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.3it/s 0.4s0.9s
#                    all         46         23      0.908      0.435      0.592      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      4.08G     0.8781      0.519      1.051          7        512: 100% ━━━━━━━━━━━━ 14/14 3.4it/s 4.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s1.0s
#                    all         46         23      0.692      0.609      0.659      0.443
# EarlyStopping: Training stopped early as no improvement observed in last 15 epochs. Best results observed at epoch 36, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 51 epochs completed in 0.072 hours.
# Optimizer stripped from C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\models\fine_tuning\pools_fine_tuning_v3\weights\last.pt, 52.0MB
# Optimizer stripped from C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\models\fine_tuning\pools_fine_tuning_v3\weights\best.pt, 52.0MB
#
# Validating C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\models\fine_tuning\pools_fine_tuning_v3\weights\best.pt...
# Ultralytics 8.3.218  Python-3.10.18 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# Model summary (fused): 92 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.7it/s 0.4s0.9s
#                    all         46         23          1      0.516      0.732      0.516
# Speed: 0.1ms preprocess, 5.5ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\models\fine_tuning\pools_fine_tuning_v3

# %%
# Insira o modelo treinado
best_model = YOLO("../models/fine_tuning/pools_fine_tuning_v3/weights/best.pt")

preds = best_model.predict("../dataset/sao_paulo_random_images/images/sp_Zona_Sul_0308_-23.636389_-46.702231.png", iou=0.5)
preds2 = best_model.predict("../dataset/sao_paulo_random_images/images/sp_Centro_0023_-23.551169_-46.614799.png", iou=0.05)
preds3 = best_model.predict("../dataset/fine_tuning/yolo_dataset_split/test/images/sp_Alto_de_Pinheiros_0258_-23.552857_-46.711000.png", iou=0.05)

result_img = preds[0].plot()    # BGR
result_img = cv2.cvtColor(result_img, cv2.COLOR_BGR2RGB)

result_img2 = preds2[0].plot()  # BGR
result_img2 = cv2.cvtColor(result_img2, cv2.COLOR_BGR2RGB)

result_img3 = preds3[0].plot()  # BGR
result_img3 = cv2.cvtColor(result_img3, cv2.COLOR_BGR2RGB)

plt.imshow(result_img)
plt.axis("off")
plt.show()

plt.imshow(result_img2)
plt.axis("off")
plt.show()

plt.imshow(result_img3)
plt.axis("off")
plt.show()
# Out:
# image 1/1 C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\notebooks\..\dataset\sao_paulo_random_images\images\sp_Zona_Sul_0308_-23.636389_-46.702231.png: 512x512 5 pools, 26.0ms
# Speed: 1.7ms preprocess, 26.0ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\notebooks\..\dataset\sao_paulo_random_images\images\sp_Centro_0023_-23.551169_-46.614799.png: 512x512 2 pools, 11.6ms
# Speed: 0.8ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 C:\Users\Seares\Desktop\Programao\Projetos\Cases Tcnicos\CloudWalk-case\notebooks\..\dataset\fine_tuning\yolo_dataset_split\test\images\sp_Alto_de_Pinheiros_0258_-23.552857_-46.711000.png: 512x512 1 pool, 11.5ms
# Speed: 0.9ms preprocess, 11.5ms inference, 3.2ms postprocess per image at shape (1, 3, 512, 512)
